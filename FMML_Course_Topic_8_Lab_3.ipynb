# %% [markdown]
# <a href="https://colab.research.google.com/github/Bondalapati-Haritha/FMML-LAB-ASSIGNMENT/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-25 07:52:35--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json.1’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   361MB/s    in 0.2s
#
# 2024-03-25 07:52:35 (361 MB/s) - ‘arxiv-paper-data.json.1’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 36087   1406.2234v1  We report our initial investigations into reli...    cs
# 25004  1501.07338v1  We recently have witnessed many ground-breakin...    cs
# 23798   1406.5212v1  We present convolutional neural networks for t...    cs
# 32293   1403.7471v3  This paper presents an approximate method for ...    cs
# 8621   1707.09240v2  Human pose forecasting is an important problem...    cs
# ...             ...                                                ...   ...
# 3539   1711.06221v1  We introduce a new, systematic framework for v...  stat
# 12354  1712.05438v1  The superior performance of ensemble methods w...  stat
# 8542   1704.00648v2  We present a new approach to learn compressibl...    cs
# 4092   1612.00901v1  Semantic sparsity is a common challenge in str...    cs
# 25025  1504.01800v2  We propose a nonrigid registration approach fo...    cs
#
#                                                    title  year  \
# 36087  Fault-Tolerant, but Paradoxical Path-Finding i...  2014
# 25004  On Vectorization of Deep Convolutional Neural ...  2015
# 23798    R-CNNs for Pose Estimation and Action Detection  2014
# 32293       Approximate Decentralized Bayesian Inference  2014
# 8621       Human Pose Forecasting via Deep Markov Models  2017
# ...                                                  ...   ...
# 3539   A Forward-Backward Approach for Visualizing In...  2017
# 12354  Stochastic Particle Gradient Descent for Infin...  2017
# 8542   Soft-to-Hard Vector Quantization for End-to-En...  2017
# 4092   Commonly Uncommon: Semantic Sparsity in Situat...  2016
# 25025  A Multicomponent Approach to Nonrigid Registra...  2015
#
#                                                 keywords
# 36087  [investigations, reliability, sidewalks, const...
# 25004  [witnessed, generated, convolutional, architec...
# 23798  [convolutional, prediction, classification, un...
# 32293  [approximate, performing, inference, condition...
# 8621   [forecasting, important, applications, interac...
# ...                                                  ...
# 3539   [introduce, systematic, framework, visualizing...
# 12354  [performance, optimization, dimensional, regul...
# 8542   [compressible, representations, architectures,...
# 4092   [challenge, structured, classification, predic...
# 25025  [registration, diffusion, multicomponent, info...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 36087    [investigations, reliability, sidewalks, const...
# 25004    [witnessed, generated, convolutional, architec...
# 23798    [convolutional, prediction, classification, un...
# 32293    [approximate, performing, inference, condition...
# 8621     [forecasting, important, applications, interac...
#                                ...
# 206      [convolutional, potential, applications, perfo...
# 12721    [automatic, localizing, identifying, character...
# 3409     [performed, radiation, abnormalities, stochast...
# 40577    [optimization, framework, explicitly, heteroge...
# 39561    [annotation, component, components, extraction...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8810 words.
# Out of those 4523 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="1b4f0e98-66b4-4d36-93eb-d5eac8e6eb59" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1b4f0e98-66b4-4d36-93eb-d5eac8e6eb59")) {                    Plotly.newPlot(                        "1b4f0e98-66b4-4d36-93eb-d5eac8e6eb59",                        [{"x":["represent","development","probability","accumulating","professional","addressed","instructions","reliability","construction","developers","processes","associated","polynomials","uniformly","investigations","alternative","construct","conservative","unreliable","increases","destination","introduce","conceptual","architectures","developed","performance","parallelism","abstracted","literature","implementation","convolutional","operators","algorithmic","attention","processing","generated","framework","illustrated","facilitate","understand","computation","vectorization","implementations","dedicated","vectorized","witnessed","classification","prediction","functions","additionally","classifying","approaches","depending","estimation","simultaneously","unconstrained","localizing","challenging","detection","procedure","dependencies","additional","decentralized","independence","distributed","including","variational","approximate","addresses","inference","advantages","individual","posterior","combination","conditional","application","computational","demonstrate","optimization","performing","experiments","likelihood","posteriors","combining","predictive","synthetic","sequences","evaluation","applications","promising","autonomous","threefold","classifier","important","difficulty","contributions","generative","autoencoders","subjective","algorithms","estimating","milliseconds","repeatedly","forecasts","surveillance","continues","coordinate","forecasting","interaction","assembling","techniques","rationale","contrasts","quantities","possibility","manuscript","experiment","manipulation","capability","drosophila","experimental","manipulating","otherwise","association","performed","orientation","investigate","computers","automated","providing","algorithm","explorations","introduced","sensitive","typically","predictions","relevance","nonlinear","characterize","difficult","decomposing","particular","interpreting","summarize","recognition","distributions","variables","propagation","especially","technique","structure","transparency","respectively","theoretical","accommodate","demonstrating","pointwise","comparison","outperforms","constructing","recommendation","collaborative","asymptotic","permutation","analyzing","permutations","extending","favorable","factorization","representation","independent","statistical","objective","surrogate","simulated","adversary","stochastic","evaluated","unexplored","improving","parameter","automatically","controlled","simulation","simulations","parameters","accurately","informative","efficiently","intelligent","scalability","corresponds","footprint","synchronous","advantage","hyperparameters","optimizers","minimizing","reinforcement","computations"],"y":[94,117,176,4,7,39,7,26,61,11,93,103,7,10,10,111,82,6,10,55,5,332,32,115,203,895,11,3,133,147,370,48,36,164,294,178,553,18,40,68,145,2,39,24,2,13,504,244,214,80,41,465,35,210,125,26,12,299,354,119,38,101,10,32,111,233,49,114,43,217,73,111,38,131,113,250,329,589,332,82,622,55,3,121,51,140,103,241,454,118,56,3,149,343,41,46,114,18,29,622,63,4,7,5,39,6,36,24,82,4,365,2,8,14,37,10,81,18,63,3,408,6,17,30,133,32,151,17,114,92,792,3,117,63,115,80,27,61,47,161,10,238,7,15,402,107,134,60,119,237,310,3,84,185,10,33,4,149,249,35,28,30,21,8,68,9,31,13,37,358,131,132,172,12,56,14,135,151,7,97,133,187,35,75,60,238,68,44,159,54,31,16,5,3,86,16,5,41,112,29],"type":"bar"},{"x":["represent","development","probability","accumulat ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4523,), (4523, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8008333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Specifying</span> <span style=''>nonspecific</span> <span style=''>evidence</span> <br/><br/><span style=''>In</span> <span style=''>an</span> <span style=''>earlier</span> <span style=''>article</span> <span style=''>J</span> <span style=''>Schubert</span> <span style=''>On</span> <span style=''>nonspecific</span> <span style=''>evidence</span> <span style=''>Int</span> <span style=''>J</span> <span style=''>Intell</span> <span style=''>Syst</span> <span style=''>8(6)</span> <span style=''>711</span> <span style=''>725</span> <span style=''>(1993)</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>established</span> <span style=''>within</span> <span style=''>Dempster</span> <span style=''>Shafer</span> <span style=''>theory</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>criterion</span> <span style=''>function</span> <span style=''>called</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>metaconflict</span> <span style=''>function</span> <span style=''>With</span> <span style=''>this</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>criterion</span> <span style=''>we</span> <span style=''>can</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>partition</span> <span style=''>into</span> <span style=''>subsets</span> <span style=''>a</span> <span style=''>set</span> <span style=''>of</span> <span style=''>several</span> <span style=''>pieces</span> <span style=''>of</span> <span style=''>evidence</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.7777777777777778);'>propositions</span> <span style=''>that</span> <span style=''>are</span> <span style=''>weakly</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>specified</span> <span style=''>in</span> <span style=''>the</span> <span style=''>sense</span> <span style=''>that</span> <span style=''>it</span> <span style=''>may</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.6129032258064516);'>uncertain</span> <span style=''>to</span> <span style=''>which</span> <span style=''>event</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>proposition</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.7777777777777778);'>referring</span> <span style=''>Each</span> <span style=''>subset</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>partitioning</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.44761904761904764);'>representing</span> <span style=''>a</span> <span style=''>separate</span> <span style=''>event</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>metaconflict</span> <span style=''>function</span> <span style=''>was</span> <span style=''>derived</span> <span style=''>as</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.6666666666666666);'>plausibility</span> <span style=''>that</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>partitioning</span> <span style=''>is</span> <span style=''>correct</span> <span style=''>when</span> <span style=''>viewing</span> <span style=''>the</span> <span style=''>conflict</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>Dempsters</span> <span style=''>rule</span> <span style=''>within</span> <span style=''>each</span> <span style=''>subset</span> <span style=''>as</span> <span style=''>a</span> <span style=''>newly</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constructed</span> <span style=''>piece</span> <span style=''>of</span> <span style=''>metalevel</span> <span style=''>evidence</span> <span style=''>with</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 1.0);'> ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Robust</span> <span style=''>Subspace</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Clustering</span> <span style=''>via</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Thresholding</span> <br/><br/><span style=''>The</span> <span style=''>problem</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>noisy</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>incompletely</span> <span style=''>observed</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>data</span> <span style=''>points</span> <span style=''>into</span> <span style=''>a</span> <span style=''>union</span> <span style=''>of</span> <span style=''>low</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>subspaces</span> <span style=''>and</span> <span style=''>a</span> <span style=''>set</span> <span style=''>of</span> <span style=''>outliers</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>considered</span> <span style=''>The</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>subspaces</span> <span style=''>their</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensions</span> <span style=''>and</span> <span style=''>their</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>orientations</span> <span style=''>are</span> <span style=''>assumed</span> <span style=''>unknown</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>simple</span> <span style=''>low</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>complexity</span> <span style=''>subspace</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>which</span> <span style=''>applies</span> <span style=''>spectral</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>to</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>adjacency</span> <span style=''>matrix</span> <span style=''>obtained</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>thresholding</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>correlations</span> <span style=''>between</span> <span style=''>data</span> <span style=''>points</span> <span style=''>In</span> <span style=''>other</span> <span style=''>words</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>adjacency</span> <span style=''>matrix</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>constructed</span> <span style=''>from</span> <span style=''>the</span> <span style=''>nearest</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>neighbors</span> <span style=''>of</span> <span style=''>each</span> <span style=''>data</span> <span style=''>point</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>spherical</span> <span style=''>distance</span> <span style=''>A</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>analysis</span> <span style=''>shows</span> <span style=''>that</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>exhibits</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>robustness</span> <span style=''>to</span> <span style=''>additive</span> <span style=''>noise</span> <span style=''>and</span> <span style=''>succeeds</span> <span style=''>even</span> <span style=''>when</spa ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Selective</span> <span style=''>Greedy</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Equivalence</span> <span style=''>Search</span> <span style=''>Finding</span> <span style=''>Optimal</span> <span style=''>Bayesian</span> <span style=''>Networks</span> <span style=''>Using</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Polynomial</span> <span style=''>Number</span> <span style=''>of</span> <span style=''>Score</span> <span style='background-color:rgba(0, 255, 0, 0.3333333333333333);'>Evaluations</span> <br/><br/><span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduce</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Selective</span> <span style=''>Greedy</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Equivalence</span> <span style=''>Search</span> <span style=''>(SGES)</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>restricted</span> <span style=''>version</span> <span style=''>of</span> <span style=''>Greedy</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Equivalence</span> <span style=''>Search</span> <span style=''>(GES)</span> <span style=''>SGES</span> <span style=''>retains</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.6612903225806452);'>asymptotic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>correctness</span> <span style=''>of</span> <span style=''>GES</span> <span style=''>but</span> <span style=''>unlike</span> <span style=''>GES</span> <span style=''>has</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>polynomial</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style='background-color:rgba(255, 0, 0, 0.32163742690058483);'>guarantees</span> <span style=''>In</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>particular</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>when</span> <span style=''>data</span> <span style=''>are</span> <span style=''>sampled</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>independently</span> <span style=''>from</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style=''>that</span> <span style=''>is</span> <span style=''>perfect</span> <span style=''>with</span> <span style=''>respect</span> <span style=''>to</span> <span style=''>a</span> <span style=''>DAG</span> <span style=''>cal</span> <span style=''>G</span> <span style=''>defined</span> <span style=''>over</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observable</span> <span style='background-color:rgba(255, 0, 0, 0.3215189873417721);'>variables</span> <span style=''>then</span> <span style=''>in</span> <span style=''>the</span> <span style=''>limit</span> <span style=''>of</span> <span style=''>large</span> <span style=''>data</span> <span style=''>SGES</span> <span style=''>will</span> <span style=''>identify</span> <span style=''>cal</span> <span style=''>Gs</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>equivalence</span> <span style=''>class</span> <span style=''>after</span> <span style=''>a</span> <span style=''>number</span> <span style=''>of</span> <span style=''>score</span> <span style='background-color:rgba(0, 255, 0, 0.3333333333333333);'>evaluations</span> <span style=''>that</span> <span style=''>is</span> <span style=''>(1)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>polynomial</span> <span style=''>in</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>nodes</span> <span style=''>and</span> <span style=''>(2)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>exponential</span> <span style=''>in</span> <span style=''>various</span> <span style='background-c ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Geometric</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Framework</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Convolutional</span> <span style=''>Neural</span> <span style=''>Networks</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>geometric</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>for</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>is</span> <span style=''>proposed</span> <span style=''>This</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>uses</span> <span style=''>the</span> <span style=''>inner</span> <span style=''>product</span> <span style=''>space</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>underlying</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameter</span> <span style=''>set</span> <span style=''>to</span> <span style=''>perform</span> <span style=''>gradient</span> <span style=''>descent</span> <span style=''>not</span> <span style=''>in</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>component</span> <span style=''>based</span> <span style=''>form</span> <span style=''>but</span> <span style=''>in</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>coordinate</span> <span style=''>free</span> <span style=''>manner</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Convolutional</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>described</span> <span style=''>in</span> <span style=''>this</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>in</span> <span style=''>a</span> <span style=''>compact</span> <span style=''>form</span> <span style=''>with</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>gradients</span> <span style=''>of</span> <span style=''>standard</span> <span style=''>and</span> <span style=''>higher</span> <span style=''>order</span> <span style=''>loss</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>calculated</span> <span style=''>for</span> <span style=''>each</span> <span style=''>layer</span> <span style=''>of</span> <span style=''>the</span> <span style=''>network</span> <span style=''>This</span> <span style=''>approach</span> <span style=''>can</span> <span style=''>be</span> <span style=''>applied</span> <span style=''>to</span> <span style=''>other</span> <span style=''>network</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structures</span> <span style=''>and</span> <span style=''>provides</span> <span style=''>a</span> <span style=''>basis</span> <span style=''>on</span> <span style=''>which</span> <span style=''>to</span> <span style=''>create</span> <span style=''>new</span> <span style=''>networks</span> <br/><br/>

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	automatic (0.07231920199501247)
# 	processing (0.10473815461346633)
# 	segmentation (0.0773067331670823)
# 	challenging (0.10651941574634842)
# 	information (0.25543284645529035)
# 	different (0.26505165657285357)
# 	detection (0.1261132882080513)
# 	experimental (0.14535090844317777)
# 	convolutional (0.13181332383327396)
# 	recognition (0.14321339508371927)
#
# Some Statistics words are:
# 	variables (0.13095835423983943)
# 	numerical (0.10888108379327646)
# 	algorithm (0.36828901154039134)
# 	stochastic (0.14601103863522327)
# 	estimation (0.17862518815855494)
# 	distribution (0.1741093828399398)
# 	statistical (0.1545408931259408)
# 	dimensional (0.18615153035624687)
# 	inference (0.2042147516307075)
# 	regression (0.1726041144004014)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="2480c663-b2e0-473a-8392-a1d16d4d0a22" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2480c663-b2e0-473a-8392-a1d16d4d0a22")) {                    Plotly.newPlot(                        "2480c663-b2e0-473a-8392-a1d16d4d0a22",                        [{"x":["represent","development","probability","accumulating","professional","addressed","instructions","reliability","construction","developers","processes","associated","polynomials","uniformly","investigations","alternative","construct","conservative","unreliable","increases","destination","introduce","conceptual","architectures","developed","performance","parallelism","abstracted","literature","implementation","convolutional","operators","algorithmic","attention","processing","generated","framework","illustrated","facilitate","understand","computation","vectorization","implementations","dedicated","vectorized","witnessed","classification","prediction","functions","additionally","classifying","approaches","depending","estimation","simultaneously","unconstrained","localizing","challenging","detection","procedure","dependencies","additional","decentralized","independence","distributed","including","variational","approximate","addresses","inference","advantages","individual","posterior","combination","conditional","application","computational","demonstrate","optimization","performing","experiments","likelihood","posteriors","combining","predictive","synthetic","sequences","evaluation","applications","promising","autonomous","threefold","classifier","important","difficulty","contributions","generative","autoencoders","subjective","algorithms","estimating","milliseconds","repeatedly","forecasts","surveillance","continues","coordinate","forecasting","interaction","assembling","techniques","rationale","contrasts","quantities","possibility","manuscript","experiment","manipulation","capability","drosophila","experimental","manipulating","otherwise","association","performed","orientation","investigate","computers","automated","providing","algorithm","explorations","introduced","sensitive","typically","predictions","relevance","nonlinear","characterize","difficult","decomposing","particular","interpreting","summarize","recognition","distributions","variables","propagation","especially","technique","structure","transparency","respectively","theoretical","accommodate","demonstrating","pointwise","comparison","outperforms","constructing","recommendation","collaborative","asymptotic","permutation","analyzing","permutations","extending","favorable","factorization","representation","independent","statistical","objective","surrogate","simulated","adversary","stochastic","evaluated","unexplored","improving","parameter","automatically","controlled","simulation","simulations","parameters","accurately","informative","efficiently","intelligent","scalability","corresponds","footprint","synchronous","advantage","hyperparameters","optimizers","minimizing","reinforcement","computations","asynchronous","significantly","screening","comparable","regularity","consistency","numerical","conditions","establish","assumption","demonstrated","minimization","equivalence","knowledge","outperform","autoencoder","extracting","evolution","constitute","components","expanding","leveraging","representational","robustness","presented","operations","architecture","indicates","learnable","multiplication","arithmetic","explicitly","operation","perceptual","cognitive","introduces","specifically","furthermore","comparably","deployments","extensively","activations","contemporary","situations","fundamental","transfers","exploiting","accelerator","accumulation","efficient","requirements","assistants","electronic","maintainin ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	downweighting
# 	unsatisfying
# 	intercept
# 	affirmative
# 	randomforest
# 	bernstein
# 	repertoires
# 	indiscriminate
# 	bernsteins
# 	marginalize
# 	concordance
# 	censoring
# 	determinants
# 	electroencephalography
# 	unprocessed
# 	connectome
# 	chemometrics
# 	inverting
# 	confounders
# 	sacrifice
# Some words which never appear in Statistics papers:
# 	abstracted
# 	vectorized
# 	localizing
# 	milliseconds
# 	drosophila
# 	deployments
# 	accelerator
# 	assistants
# 	morphable
# 	bitstreams
# 	articulated
# 	prisoners
# 	cooperative
# 	hypernyms
# 	agglutinative
# 	hollywood
# 	appearances
# 	coreference
# 	actionable
# 	preparation

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.068143466388488e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7608333333333334
